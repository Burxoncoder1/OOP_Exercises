# %% [markdown]
# <a href="https://colab.research.google.com/github/BURXON777/OOP_Exercises/blob/main/OOP_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# # -Oson1 topshiriq
# class Oson1:
#   def __init__(self,a):
#     self.a = a
#   def output_a(self):
#     return self.a
# integer = Oson1(100)
# integer.output_a()
    
# # -Oson2 topshiriq
# class Oson2:
#   def __init__(self,a,b):
#     self.a = a
#     self.b = b
#   def summa(self):
#     return self.a + self.b
# yigindi = Oson2(10,5)
# yigindi.summa()

# # -Oson3 topshiriq
# class Oson3:
#   def __init__(self,a):
#     self.a = a
#   def plus_minus(self):
#     if self.a > 0:
#       print("Musbat")
#     else: print("Manfiy")
# pm = Oson3(-1)
# pm.plus_minus()

# -Oson4 topshiriq
# class Oson4:
#   def __init__(self,a):
#     self.a = a
#   def odd_even(self):
#     if self.a % 2 == 0:
#       print("Juft")
#     else: print("Toq")
# jt = Oson4(13)
# jt.odd_even()

# -Oson5 topshiriq
# class Oson5:
#   def __init__(self,a,b):
#     self.a = a
#     self.b = b
#   def daraja(self):
#     return self.a ** self.b
# daraja = Oson5(2,5)
# daraja.daraja()

# -MyClass8 topshirigi --------------------------------
# class MyClass8:
#   def __init__(self,numbers):
#     self.numbers = []
#   def compare_lists(self,new_list):
#     if sum(new_list) > sum(self.numbers):
#       print(new_list)
#     else:
#       print(self.numbers)
#     # print(new_list) if sum(new_list) > sum(self.numbers) else self.numbers

# -MyClass10 topshirigi
# class MyClass10:
#   def __init__(self):
#     self.numbers = []
#   def divide(self,d)
#     res = []
#     for i in self.numbers:
#       if i % d == 0:
#         res.append(i)
#           return res
        
############ Vorisdorlik-1#########
# class Texnika:
#   def __init__(self,brand,model,type):
#     self.brand = brand
#     self.model = model
#     self.type = type
#   def info(self):
#     print(f"Brend{self.brand},Model{self.model},Turi{self.type}")
# # Stati = Texnika('Iphone','X max-','gtb')
# # Stati.info()
  
# class Notebooks(Texnika):
#   def __init__(self,brand,model,type,video_card,ram,display):
#     super().__init__(brand,model,type)
#     self.video_card = video_card
#     self.ram = ram
#     self.display = display
#   def more_info(self):
#     print(f"Brend >> {self.brand},\nMadeli >> {self.model},\nTuri >> {self.type},\nVideo_kartasi >> {self.video_card},\nRam >> {self.ram},\nDisplayi >> {self.display}")
# ##masalan
# Notebooks('Asus', 'X', 'zo\'r', 'GTX', '64', '19').more_info()

# class Televisions(Texnika):
#   def __init__(self,brand,model,type,size,display):
#     super().__init__(brand,model,type)
#     self.size = size
#     self.display = display
#   def more_info(self):
#     print(f"Brend >> {self.brand},\nMadeli >> {self.model},\nTuri >> {self.type},\nSize >> {self.size},\nDisplayi >> {self.display}")
##Televisions().more_info()

# class Smartphones(Texnika):
#   def __init__(self,brand, model, type, size, sim_count):
#     super().__init__(brand, model, type)
#     self.size = size
#     self.sim_count = sim_count
#   def more_info(self):
#     print(f"Brend >> {self.brand},\nMadeli >> {self.model},\nTuri >> {self.type},\nSize >> {self.size},\nSim_count >> {self.sim_count}")
###Smartphones().more_info()



##############Vorisdorlik-2###########
# class Transport:
#   def __init__(self,brand, model, type):
#     self.brand = brand
#     self.model = model
#     self.type = type
#   def info(self):
#     print(f"Brend >> {self.brand}.\nMadel >> {self.model},\nTuri >> {self.type}")
# ###Transport('dfdf','fdfd','dfdfdf',).info()

# class ElentroCars(Transport):
#   def __init__(self,brand, model, type, battery_life, chargin_time):
#     super().__init__(brand, model, type)
#     self.battery_life = battery_life
#     self.chargin_time = chargin_time
#   def more_info(self):
#     print(f"Brend >> {self.brand}.\nMadel >> {self.model},\nTuri >> {self.type},\nBatarya_zayadi >> {self.battery_life},\nZaryadlash_vaqti >> {self.chargin_time}")
# ###ElentroCars('dfdf','fdfd','dfdfdf','sfsfs','vsdvdfsdf').more_info()
  
# class SportCars(Transport):
#   def __init__(self,brand, model, type, motor, color):
#     super().__init__(brand, model, type)
#     self.motor = motor
#     self.color = color
#   def more_info(self):
#     print(f"Brend >> {self.brand}.\nMadel >> {self.model},\nTuri >> {self.type},\nMotori >> {self.motor},\nRangi >> {self.color}")
# ###SportCars('dfdfd','dfdfdfd','fsfsfsfs','sfsfsfs','fddgfdf').more_info()

# class Truck(Transport):
#   def __init__(self,brand, model, type, height, long, wieght):
#     super().__init__(brand, model, type)
#     self.height = height
#     self.long = long
#     self.wieght = wieght
#   def more_info(self):
#     print(f"Brend >> {self.brand}.\nMadel >> {self.model},\nTuri >> {self.type},\nBalandligi >> {self.height},\nUzunligi >> {self.long},\nVazni >> { self.wieght}")
# ###Truck().more_info()
